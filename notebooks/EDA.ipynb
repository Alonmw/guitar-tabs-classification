# %% [markdown]
# Notebook goal: perform EDA on preprocessed data under /data/preprocessed/

# %% [markdown]
# Import necessary modules

# %%
import numpy as np
import os
import matplotlib.pyplot as plt
import librosa.display
import src.visualization as visualization

# %%
ROOT_DIR = os.path.dirname(os.getcwd())
p_data_dir = ROOT_DIR + '\\data\\preprocessed\\'
p_data_dir
# Out:
# 'C:\\Users\\User\\PycharmProjects\\guitar-tabs-classification\\data\\preprocessed\\'

# %%
test_path = ROOT_DIR + '/data/preprocessed/A0/A0-fpick/A0_fingerpick-01.npy'

# %%
test_file = np.load(test_path)

# %%
visualization.plot_cqt(test_file)
